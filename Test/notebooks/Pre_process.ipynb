# %%
import multiprocessing
import os
import pandas as pd
import string
import re
import langid

import numpy as np
import gzip

from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords

BASE_FILE = '../data/base_titulos_english.txt'
OUT_FILE = '../data/all_titles_sw.txt.gz'

# %% [markdown]
# ## Read Data

# %%
file = open(BASE_FILE, 'r')
data = file.readlines()
file.close()
sw_path = os.path.abspath("../stopwords.txt")
sw = stopwords.words(sw_path)

# %% [markdown]
# ## Remove punctuation, stopwords and invalid text

# %%
def to_lower(text):
    text = [word.lower() for word in text.split()]
    return " ".join(text)

# %%
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# %%
def remove_stopwords(text, sw):
    text = [word for word in text.split() if word not in sw]
    return " ".join(text)

# %%
def remove_invalid(text):
    noise_file = open('../noise.txt', 'r')
    noise = noise_file.read()
    text = remove_punctuation(text)
    #text = re.sub('[^A-Z a-z _-]', '', text)
    #text = re.sub('0-9', '', text)
    text = re.sub('\n', ' ', text)
    text = re.sub(' +', ' ', text)
    text = text.split(' ')
    text2 = ''
    for index, word in enumerate(text):
        if(len(word) < 2 or len(word) > 16):
            text.pop(index)
        elif word in noise:
            text.pop(index)
        elif re.search('\d+', word):
            text.pop(index)
    for word in text:
        text2 += word + ' '
    text2 = text2[:-1]
    return text2

# %%
data_clean = []
for line in data:
    text = remove_punctuation(line)
    text = to_lower(text)
    #text = remove_stopwords(text, sw)
    text = remove_invalid(text)
    data_clean.append(text)
data_clean
# Out:
# ['corneal endothelial deposits associated with rifabutin use',
#  'extranodal bcell lymphoma of the uvea case report',
#  'eyelid swelling as the only manifestation of ocular sarcoidosis',
#  'cytomegalovirus glycoprotein genotypes and central nervous system disease aids patients',
#  'and lymphocyte correlate to intensity of interface hepatitis chronic hepatitis',
#  'clinical aspects of influenza h1n1 hivinfected individuals são paulo during the pandemic of',
#  'tissue and serum immune response chronic hepatitis with mild histological lesions',
#  'immunogenicity and reactogenicity of influenza h1n1 inactivated monovalent nonadjuvanted vaccine elderly and patients',
#  'hepatitis virus and human tlymphotropic virus coinfection epidemiological clinical laboratory and features',
#  'estimation of initial condition heat conduction by neural network',
#  'estimation of boundary conditions heat transfer by neural networks',
#  'neural network based models the inversion of temperature vertical profiles from radiation data§',
#  'an inverse vibration problem solved by an artificial neural network',
#  'unified regularization theory the maximum nonextensive entropy principle',
#  'representative airglow volume emission profile fromrocketborne photometer data by an artificial neural network technique',
#  'embedding ann uav for surveillance case study for urban areas observation',
#  'image matching applied to autonomous navigation of unmanned aerial vehicles',
#  'atmospheric temperature retrieval using radial basis function neural network',
#  'rapid tolerance to and crosstolerance between ethanol and in mice',
#  'sr prevents spatial learning deficit a morristype water maze mice',
#  'potentiation of penile erection and yawning responses to apomorphine by cannabinoid receptor antagonist rats',
#  'acquisition of ethanol in two rats lines used as genetic models of anxiety',
#  'activation of adenosine receptors reduces anxietylike behavior during acute ethanol withdrawal hangover mice',
#  'effects of ethanol on locomotor and anxietylike behaviors and the acquisition of ethanol intake lewis and spontaneously hypertensive rats',
#  'growth and ion uptake annona muricata and squamosa subjected to salt stress',
#  'oogenesis pattern and type of ovariole of the parasitoid palmistichus elaeisis hymenoptera eulophidae',
#  'admixtures characterisation and control by chemical and rheological methods',
#  'concrete robustness continuous production regarding fresh and hardened state properties',
#  'influence of autonomic neuropathy upon left ventricular dysfunction insulin dependent diabetic patients',
#  'transesophageal echocardiography and transcranial doppler monitoring coronary surgery without cardiopulmonary bypass preliminary results',
#  'importance of intraoperative transesophageal echocardiography during coronary artery surgery without cardiopulmonary bypass',
#  'serum insulin levels blood pressure profile and left ventricular mass nonobese hypertensive patients',
#  'effect of blood glucose on left ventricular mass patients with hypertension and type diabetes mellitus',
#  'assessment of the pulmonary venous an indicator of increased pulmonary in congenital cardiac malformations',
#  'cine magnetic resonance imaging and color doppler mapping displays of velocity spatial acceleration and jet formation comparative vitro study',
#  'demonstration of dual parallel jet interaction an vitro model of multivalvular disease by use of optical visualization and color doppler mapping',
#  'influence of the coanda effect on color doppler jet area and color encoding vitro studies using color doppler mapping',
#  'new method for noninvasive estimation of ventricular septal defect shunt by color doppler mapping imaging of the laminar convergence region on the left septal surface',
#  'effects of pressure and volume of the receiving chamber on the spatial distribution of regurgitant jets as imaged by color doppler mapping',
#  'new method for quantification of regurgitant rate using color doppler imaging of the convergence region proximal to discrete orifice an vitro study',
#  'left coronary artery communication late postoperative complication after the takeuchi procedure for repair of anomalous origin of left coronary artery from the pulmonary artery detected by color doppler mapping',
#  'cardiovascular effects of sucessful renal transplantation 1year sequencial study of left ventricular morphology and function and blood pressure profile',
#  'mildly symptomatic chronic mitral regurgitation analysis of left ventricular systolic function and mitral regurgitant fraction under pharmacological influence study',
#  'association of pulmonary atresia with intact ventricular septum and aortic valve stenosis prenatal diagnosis',
#  'left ventricular hypertrophy evaluation obese hypertensive patients effect of left ventricular mass index criteria',
#  'doppler echocardiography relevant features diagnosis and followup of patients with aortic stenosis',
#  'role of stress echocardiography prognosis evaluation of women',
#  'effect of central hypothyroidism on dopplerderived myocardial performance index',
#  'myocardial performance index female rats with myocardial infarction relationship with ventricular function parameters by doppler echocardiography',
#  'cardioprotective effect of dexrazoxane during treatment with doxorubicin study using lowdose dobutamine stress echocardiography',
#  'immediate functional effects of left ventricular reduction doppler study the rat',
#  'myocardial dysfunction mitochondrial diabetes treated with coenzyme',
#  'performance of twodimensional doppler echocardiophy for the assessment of infart size and left ventricular function rats',
#  'impact of effective valvotomy mitral stenosis on pulmonary venous',
#  'hyperglycemia and nocturnal systolic blood pressure are associated with left ventricular hypertrophy and diastolic dysfunction hypertensive diabetic patients',
#  'the case of utilizing more strict quantitative doppler criterions for diagnosis of subclinical rheumatic carditis',
#  'rats with high left ventricular end diastolic pressure can be identified by doppler echocardiography one week after myocardial infarction',
#  'growth hormone replacement improves thyroxine biological effects implications for management of central hypothyroidism disease',
#  'diagnostic value of color mapping and doppler echocardiography the quantitation of mitral regurgitation patients with mitral valve prolapse rheumatic heart disease',
#  'what the true frequency of carditis acute rheumatic fever prospective clinical and doppler blind study of children with up to months of followup evaluation',
#  'doppler predictors of mortality female rats after myocardial infarction',
#  'dopplerderived myocardial performance index patients with impaired left ventricular relaxation and preserved systolic function',
#  'parameters and brain natriuretic peptide patients after surgical repair of tetralogy of fallot',
#  'left atrial dysfunction chagas cardiomyopathy more severe than idiopathic dilated cardiomyopathy study with realtime threedimensional echocardiography',
#  'exercise echocardiography cryopreserved aortic homografts comparison of prototype stentless stented bioprosthesis and native aortic valves',
#  'diagnosis of subclinical central hypothyroidism patients with disease by doppler echocardiography',
#  'pulmonary venous index as predictor of pulmonary vascular resistance variability congenital heart disease with increased pulmonary a comparative study before and after oxygen inhalation',
#  'criteria for mitral regurgitation classification were inadequate for dilated cardiomyopathy',
#  'preoperative left ventricular ejection fraction and left atrium reverse remodeling after mitral regurgitation surgery',
#  'focused cardiac ultrasound using pocketsize device the emergency room',
#  'left atrial volume determinants patients with nonischemic dilated cardiomyopathy',
#  'diagnostic and prognostic value of right ventricular strain patients with pulmonary arterial hypertension and relatively preserved functional capacity studied with echocardiography and magnetic resonance',
#  'prognostic value of realtime threedimensional echocardiography compared to twodimensional echocardiography patients with systolic heart failure',
#  'atualização das diretrizes brasileiras de valvopatias abordagem das lesões anatomicamente importantes',
#  'training program for cardiology residents to perform focused cardiac ultrasound examination with portable device',
#  'right coronary artery fistula with congestive heart failure the neonate doppler diagnosis and closure with detachable balloon',
#  'caracterização preliminar de amostras do vírus da diarréia viral bovina bvdv isoladas no brasil',
#  'identificação do vírus da diarréia viral bovina tipo bvdv2 no sul do brasil',
#  'diversidade antigênica de amostras do vírus da diarréia viral bovina isoladas no brasil implicações para diagnóstico estratégias de imunização',
#  'production and characterization of monoclonal antibodies to brazilian isolates of bovine viral diarrhea virus',
#  'rna immunization against bovine viral diarrhea virus',
#  'phylogenetic analysis of brazilian bovine viral diarrhea virus type bvdv2 isolates evidence for subgenotype within',
#  'role of bovine viral diarrhea virus biotype the establishment of fetal infections',
#  'the envelope glycoprotein is determinant of cell culture tropism ruminant pestiviruses',
#  'involvement of bovine viral diarrhea virus locus virion assembly',
#  'the aminoterminal domain of bovine viral diarrhea virus npro protein necessary for alphabeta interferon antagonism',
#  'modulation of pkr activity cells infected by bovine viral diarrhea virus',
#  'effect of the viral protein supprosup on virulence of bovine viral diarrhea virus and induction of interferon type in calves',
#  'replicon transpackaging system reveals the requirement of nonstructural proteins for the assembly of bovine viral diarrhea virus bvdv virion',
#  'novel highly selective inhibitor of pestivirus replication that targets the viral rnadependent rna polymerase',
#  'early molecular markers predictive of dengue hemorrhagic fever',
#  'alternative complement pathway deregulation correlated with dengue severity',
#  'identification of continuous human bcell epitopes the envelope glycoprotein of dengue virus type denv3',
#  'gene expression profiling during early acute febrile stage of dengue infection can predict the disease outcome',
#  'classification of dengue fever patients based on gene expression data using support vector machines',
#  'description of prospective yellow fever vaccine cohort recife brazil',
#  'construction of yellow fever virus subgenomic replicons by yeastbased homologous recombination cloning technique',
#  'is associated with dengue severity caused by in brazilian population',
#  'complement factor gene cfh polymorphisms g257a and haplotypes are associated with protection against severe dengue phenotype possible related with high cfh expression',
#  'the eukaryotic translation initiation factor subunit protein interacts with flavivirus and may modulate yellow fever virus replication',
#  'potential biomarkers for the clinical prognosis of severe dengue',
#  'construction and characterisation of complete reverse genetics system of dengue virus type',
#  'identification of conserved and hla promiscuous tcell epitopes',
#  'diversity patterns ecology and biological activities of fungal communities associated with the endemic macroalgae across the antarctic peninsula',
#  'efficient assembly of fulllength infectious clone of brazilian ibdv isolate by homologous recombination yeast',
#  'twoplasmid strategy for engineering dengue virus type infectious clone from primary brazilian isolate',
#  'insertion and stable expression of gaussia luciferase gene by the genome of bovine viral diarrhea virus',
#  'molecular phylogeny diversity symbiosis and discover of bioactive compounds of endophytic fungi associated with the medicinal amazonian plant carapa guianensis aublet meliaceae',
#  'fulllength infectious clone of low passage dengue virus serotype from brazil',
#  'dengue the state of rio grande do norte brazil',
#  'positive igm for zika virus the cerebrospinal fluid of neonates with microcephaly brazil',
#  'use of homologous recombination yeast to create chimeric bovine viral diarrhea virus cdna clones',
#  'construction and characterization of recombinant yellow fever virus stably expressing gaussia luciferase',
#  'vivo nearinfrared fluorescence imaging of leishmania amazonensis expressing infrared fluorescence protein irfp for realtime monitoring of cutaneous leishmaniasis mice',
#  'zika antiviral chemotherapy identification of drugs and promising starting points for drug discovery from an fdaapproved library',
#  'serum profiles patients with dengue fever df and dengue hemorrhagic fever fhd by using protein array',
#  'hydrocephalus and arthrogryposis an immunocompetent mouse model of zika teratogeny developmental study',
#  'silverdoped bioactive glass as an antileishmania agent',
#  'results of zika virus zikv immunoglobulin mspecific diagnostic assay are highly correlated with detection of neutralizing antizikv antibodies neonates with congenital disease',
#  'primary dengue haemorrhagic fever patients from northeast of brazil associated with high levels of during acute phase',
#  'development and characterization of packaging cell for pseudoinfectious yellow fever virus particle generation',
#  'current status challenges and perspectives the development of vaccines against yellow fever dengue zika and chikungunya viruses',
#  'clinical pathological and antigenic aspects of bovine viral diarrhea virus bvdv type isolates identified brazil',
#  'comparison of the three most usual kind of control strategies for servo assisted motorization',
#  'biomechanical model for the determination of forces on upperextremity members during standard wheelchair propulsion',
#  'axiomatic design applied to collaborative control development',
#  'isolation of lipaseproducing yeasts from industrial oily residues different culture media',
#  'distonia laríngea de adução proposta avaliação de protocolo de',
#  'immediate effect of sounded blowing exercise the elderly voice',
#  'análise vocal laríngea na hipótese diagnóstica de nódulos cistos',
#  'the phonatory deviation diagram novel objective measurement of vocal function',
#  'measuring quality of life dysphonic patients systematic review of content development patientreported outcomes measures',
#  'resolution of vocal fold polyps with conservative treatment',
#  'diagrama de desvio fonatório análise pré pósterapia vocal',
#  'intensive shortterm voice therapy the brazilian experience',
#  'manifestações faringolaríngeas da síndrome póspoliomielite',
#  'crosscultural adaptation of the brazilian version of the protocol evaluation of the ability to sing easily',
#  'managing dysphonia occupational voice users',
#  'efficiency and cutoff values of selfassessment instruments on the impact of voice problem',
#  'perceptual error analysis of human and synthesized voices',
#  'dysphonia severity degree and phonation onset latency laryngeal adductor dystonia',
#  'relationship between chemical structure dissociation constants and biological activity of three alkaloids',
#  'in vitro relationship between spasmolitics potency of alkaloids and their uptake by guineapig trachea',
#  'lack of chemoprevention of dietary agaricus blazei against rat colonic aberrant crypt foci',
#  'screening for vitro and vivo antitumor activities of the mushroom agaricus blazei',
#  'first report of yellow fever virus nonhuman primates the state of parana brazil',
#  'the use of hydrocolloid dressing the facial wound healing process of horse case report',
#  'dinamics of snail populations of biomphalaria under seminatural conditions',
#  'methods of malacological works schistosomiasis',
#  'the bioecology of snail vectors for schistosomiasis brazil',
#  'factors involved s mansoni infection rural areas northeast brazil',
#  'epidemiology and anthropology an integrated approach dealing with biosociocultural aspects as strategy for the control of endemic diseases',
#  'urban schistosomiasis itamaracá island pernambuco brazil epidemiological factors involved the recent endemic process',
#  'schistosomiasis control based on repeated chemotherapy a rural village of the sugarcane zone northeast brazil',
#  'historical perpective and prospects of biomedical research on parasitic diseases',
#  'specific situations related to acute schistosomiasis pernambuco brazil',
#  'evolucionary relationship and biogeography of biomphalaria with implications regarding its role as host of the human bloodfluke schistosoma mansoni',
#  'longitudinal study on the natural infection of biomphalaria straminea and glabrata by schistosoma mansoni an endemic area of schistosomiasis pernambuco brazil',
#  'evaluation of tests based on the antibody response to soluble egg antigen to differentiate acute and chronic human schistosomiais',
#  'molecular identification of symbonts from the pulmonate snail biomphalaria glabrata brazil',
#  'reliability of current estimates of schistosomiasis prevalence the rainforest zone of the state of pernambuco northeastern brazil',
#  'attaining the minimum target of resolution wha for schistosomiasis control the rainforest zone of the state of pernambuco northeastern brazil',
#  'molecular approaches for the detection of schistosoma mansoni possible applications the detection of snail infection monitoring of transmission sites and diagnosis of human infection',
#  'development of molecular approaches for the identification of transmission sites of schistosomiasis',
#  'criadouros de biomphalaria temporários permanentes jaboatão dos guararapes pe',
#  'ultrastructural cytochemical aspects of schistosoma mansoni cercaria',
#  'current epidemiological status of schistosomiasis the state of pernambuco brazil',
#  'profile of the schistosomal in pernambuco brazil',
#  'spatial distribution of schistosoma mansoni infection before and after chemotherapy with two praziquantel doses a community of pernambuco brazil',
#  'spatial patter water use and risk level assciated with the transmission of schistosomiasis on the north coast of pernambuco brazil',
#  'ultrastructural study on the morphological changes to male worms of schistosoma mansoni after vitro exposure to allicin',
#  'morphological characterization of hemocytes from biomphalaria glabrata and biomphalaria straminea',
#  'the endemisation of schistosomiasis porto de galinhas pernambuco brazil years after the first outbreak',
#  'schistosomiasis transmission and environmental change spatiotemporal analysis porto de galinhas pernambuco brazil',
#  'spatial distribution of schistosomiasis and geohelminthiasis cases the rural areas of pernambuco brazil',
#  'biological and environmental factors associated with risk of schistosomiasis mansoni transmission porto de galinhas pernambuco state brazil',
#  'evaluation of tests based on the antibody response to keyhole limpet haemocyanin and soluble egg antigen to differentiate acute and chronic human schistosomiasis mansoni',
#  'replacing oxaminiquine by praziquantel against schistosoma mansoni infection a rural community from the sugarcane zone of northeast brazil an epidemiological followup',
#  'assessment of schistosomiasis through school surveys the forest zone of pernambuco brazil',
#  'spatial distribution of schistosomiasis foci on itamaracá island pernmabuco brazil',
#  'análise espacial dos casos humanos de esquistossomose uma comunidade horticultora da zona da mata de pernambuco brasil',
#  'an ecological model for quantitative risk assessment for schistosomiasis the case of patchy environment the coastal tropical area of northeastern brazil',
#  'casos autoctones de esquistossomose mansonica criancas de recife pe',
#  'risk analysis for occurrences of schistosomiasis the coastal area of porto de galinhas pernambuco brazil',
#  'the schisto track system for gathering and monitoring epidemiological surveys by connecting geographical information systems real time',
#  'study of the snail intermediate hosts for schistosoma mansoni on itamaracá island northeast brazil spatial displacement of biomphalaria glabrata by biomphalaria straminea',
#  'using mobile technology to conduct epidemiological investigations',
#  'investigation of the positivity profile for the skin prick test children infected with parasites the metropolitan region of pernambuco northeast of brazil',
#  'first report of schistosomiasis on serrambi beach ipojuca state of pernambuco',
#  'turismo de risco para esquistossomose mansônica porto de galinhas estado de pernambuco brasil',
#  'the susceptibility of recent isolates of schistosoma mansoni to praziquantel',
#  'turismo de risco áreas vulneráveis para transmissão da esquistossomose mansônica no brasil',
#  'morbidity of mansoni schistosomiasis pernambucobrazil analysis on the temporal evolution of deaths hospital admissions and severe clinical forms',
#  'evaluation of serum levels of and in human schistosoma mansoni infection and their relationship with periportal fibrosis',
#  'transmissão urbana da esquistossomose novo cenário epidemiológico na zona da mata de pernambuco',
#  'ovarian mansons schistosomiasis rare diagnosis underestimated prevalence',
#  'quality control of the slides by katokatz method for the parasitological diagnosis of schistosomiasis infection by schistosoma mansoni',
#  'field survey using lamp assay for detection of schistosoma mansoni a lowtransmission area of schistosomiasis umbuzeiro brazil assessment human and snail samples',
#  'discurso religioso tradução uma análise crítica da tradução de termos relativos ao sacerdócio',
#  'letramentos e da identidade produ199195o do artigo por alunos de',
#  'normativismo linguístico redes sociais digitais uma análise da fanpage língua portuguesa no facebook',
#  'purification and characterization of xylanases fromaspergillus giganteus',
#  'production purification and characterization of minor form of xylanase from aspergillus versicolor',
#  'potential of antimicrobial volatile organic compounds to control sclerotinia sclerotiorum bean seeds',
#  'antimicrobial volatile organic compounds affect enzymes',
#  'volatile organic compounds produced by saccharomyces cerevisiae inhibit the vitro development of guignardia citricarpa the causal agent of citrus black spot',
#  'nematicidal effect of volatile organic compounds vocs on the plantparasitic nematode meloidogyne javanica',
#  'production of by the filamentous fungus gliocladium virens as affected by sucrose concentration',
#  'antioxidative response of the fungal plant pathogen guignardia citricarpa to antimicrobial volatile organic compounds',
#  'growth inhibition and antioxidative response of wood decay fungi exposed to plant extracts of icaseariai species',
#  'antimicrobial activity of volatile organic compounds and their effect on lipid peroxidation and electrolyte loss colletotrichum gloeosporioides and colletotrichum acutatum mycelia',
#  'proteomic response of the phytopathogen phyllosticta citricarpa to antimicrobial volatile organic compounds from saccharomyces cerevisiae',
#  'leaf extracts of casearia sylvestris and casearia decandra affect growth and production of ligninolytic enzymes wood decay basidiomycetes',
#  'potential of fumigation of orange fruits with volatile organic compounds produced by saccharomyces cerevisiae to control citrus black spot disease postharvest',
#  'sequence hierarchy a mesoproterozoic interior sag basin from basin fill to reservoir scale the tombador formation chapada diamantina basin brazil',
#  'sedimentary petrology and detrital zircon upb and luhf constraints of mesoproterozoic intracratonic sequences the espinhaço supergroup implications for the archean and proterozoic evolution of the são francisco craton',
#  'unincised fluvial and tidedominated estuarine systems from the mesoproterozoic lower tombador formation chapada diamantina basin brazil',
#  'mesoproterozoic delta systems of the açuruá formation chapada diamantina brazil',
#  'age constraints on crystaltuff from the espinhaço supergroup insight into the paleoproterozoic to mesoproterozoic intracratonic basin cycles of the congosão francisco craton',
#  'ground penetrating radar for facies architecture and highresolution stratigraphy examples from the mesoproterozoic the chapada diamantina basin brazil',
#  'japanese direct investment latin america the nineties',
#  'newborn hearing screening an outpatient model',
#  'aspectos demográficos socioeconômicos de mães atendidas um programa de triagem auditiva neonatal',
#  'indicadores de risco para perda auditiva neonatos lactentes atendidos um programa de triagem auditiva neonatal',
#  'modulation masking release using the hint psychometric functions and the effect of speech time compression',
#  'percepção da fala presença de ruído competitivo efeito da taxa de modulação do ruído mascarante',
#  'masking period patterns and forward masking for speechshaped noise',
#  'nonlinear numerical analysis the vicinity of supports of hollow core slabs',
#  'anchorage failure and shear design of hollow core',
#  'analysis of second order effects case study',
#  'automatic procedure for analysis and geometry definition of axisymmetric domes by the membrane theory with constant normal stress',
#  'numerical analysis of symmetrical and asymmetrical reinforced concrete flat slabs an integrated slab column analysis',
#  'influence of the flexibility of beams and slabs static response and dynamic properties',
#  'climatization for scheduled ripening of cajamanga',
#  'material evaluation for bagging of cantaloupe melons',
#  'economic viability of muskmelon cultivation different planting spacing brazil central region',
#  'miaqsar modeling of the protease activities and cytotoxicities of ritonavir analogs',
#  'rational design of small modified peptides as ace inhibitors',
#  'computerassisted design of novel calcium channel blockers',
#  'augmiaqspr modelling of the toxicities of anilines and phenols to vibrio fischeri and subcapitata',
#  'highly predictive hologram qsar models of cruzain inhibitors',
#  'new class of antitrypanosomal agents based on imidazopyridines',
#  'comparative study of warheads for design of cysteine protease inhibitors',
#  'computerassisted design of dualtarget compounds',
#  'mobile phone appropriation the favelas of rio de janeiro brazil',
#  'dolomitization and isotope stratigraphy of the vazante formation são francisco basin brazil',
#  'correlation of neoproterozoic sucessions south america',
#  'metallogenic evolution model for the leadzinc deposits of the são francisco craton bahia and minas gerais',
#  'uso de cera de carnaúba saco plástico poliolefínico na conservação póscolheita do maracujáamarelo',
#  'waxes and plastic film relation to the shelf life of yellow passion fruit',
#  'tratamentos físicos químicos na emergência no crescimento de plântulas de pinheira',
#  'caracterização físicoquímica de frutos de quatro cultivares de quiabo',
#  'caracterização físicoquímica de pedúnculos castanhas de clones de cajueiroanão precoce nas condições do norte de minas gerais',
#  'conservação qualidade póscolheita de quiabo sob diferentes temperaturas formas de armazenamento',
#  'effect of ph and temperature on peroxidase and activities of litchi pericarp',
#  'hemoplasma infection hivpositive patient brazil',
#  'laparoscopic cystotomy for urolith removal dogs three case reports',
#  'urethral duplication a dog case report',
#  'laparoscopic versus open splenectomy dogs',
#  'serum and urinary creactive protein concentrations dogs with leptospirosis',
#  'dystocia a cat due to an ectopic artery',
#  'exposure to leptospira spp sick dogs shelter dogs and dogs from an endemic area points to consider',
#  'design optimization and application of conventional pcr assay with an internal control for detection of ´candidatus mycoplasma turicensis´ rdna domestic cats from brazil',
#  'remoção de pino de steinmann intraabdominal por em um cão',
#  'and features of akita dogs with high and erythrocyte potassium phenotypes',
#  'presence of infectious agents and coinfections diarrheic dogs determined with realtime polymerase chain reactionbased panel',
#  'serological evidence of leptospira spp the lami tucotuco rodents ctenomys lami',
#  'hemoplasma prevalence and hematological abnormalities associated with infection three different cat populations from southern brazil',
#  'canine prostate palpation simulator as teaching tool veterinary education',
#  'toothpick as perforating splenic foreign body a dog ultrasonography diagnosis and surgical treatment',
#  'humane education brazil organisation challenges and opportunities',
#  'development of quantitative pcr for the detection of rangelia vitalii',
#  'fructosamine as tool on the evaluation of insulin resistant obese dogs',
#  'on the journey toward humane education brazil first request for total ban of harmful animal use professional and higher education',
#  'determination of absolute values of refractive index of liquids using an interferometric method',
#  'electric field assisted hydrogen fluoride etching of silica',
#  'biossegurança conhecimento adesão pelos profissionais do corpo de bombeiros militar de minas gerais',
#  'needlestick stuffs with safety device for prevention of percutaneous injuries literature review',
#  'accidents with exposure to biological stuff vaccine coverage and procedures after accidents among manicurepedicure professionals',
#  'risco oculto no segmento de estética beleza uma avaliação do conhecimento dos profissionais das práticas de biossegurança nos salões de beleza',
#  'adherence and knowledge about best practices and occupational biohazards among',
#  'registro do uso de antimicrobianos instituições de longa permanência para idosos',
#  'vestuário de profissionais de saúde como potenciais reservatórios de microrganismos uma revisão integrativa',
#  'threescale model for phdependent in clays',
#  'electroosmosis kaolinite with phdependent surface charge modelling by homogenization',
#  'threescale model of phdependent and ion transport with equilibrium adsorption kaolinite clays homogenization analysis',
#  'threescale model of phdependent and ion transport with equilibrium adsorption kaolinite clays ii effectivemedium behavior',
#  'twoscale computational model of expansive porous media',
#  'twoscale nonlocal model of swelling porous media incorporating ion size correlation effects',
#  'numerical modeling of straining the role of particle and pore size distributions',
#  'asymptotic analysis of threescale model of phdependent in clays with danckwerts boundary conditions',
#  'an adjointbased optimization method for gas production shale reservoirs',
#  'modified effective stress principle for unsaturated swelling clays derived from microstructure',
#  'highresolution magic angle spinning nuclear magnetic resonance foodstuff analysis',
#  'vitro fracture resistance of glassfiber and cast metal posts with different lengths',
#  'effect of eugenolbased endodontic sealer on the adhesion of intraradicular posts cemented after different periods',
#  'effect of different restorative procedures on the fracture resistance of teeth submitted to internal bleaching',
#  'vitro fracture resistance of glassfiber and cast metal post with different designs',
#  'effect of different restorative procedures on the fracture resistance of teeth submitted to internal bleaching',
#  'vitro fracture resistance of glassfiber and cast metal posts with different designs',
#  'environmental isolates of burkholderia pseudomallei ceara state northeastern brazil',
#  'diagnosis of burkholderia pseudomallei directly a bronchoalveolar lavage by polymerase chain reaction',
#  'inhibition of expression may suggest that is virulence factor paracoccidioides brasiliensis',
#  'paracoccidioides lutzii is an active glucanase with partial antigenic identity with brasiliensis',
#  'cyclopalladated compound induces apoptosis and autophagylike mechanisms iparacoccidioidesi and a candidate for treatment',
#  'reconstructing the fatherland german turnen southern brazil',
#  'how sensitive are ecosystem services european forest landscapes to silvicultural treatment',
#  'cohesive fire management within an uncertain environment review of risk handling and decision support systems',
#  'decision support system for assessing tradeoffs between ecosystem management goals an application portugal',
#  'addressing wildfire risk a landscapelevel scheduling model an application portugal',
#  'foreword',
#  'webbased toolbox approach to support adaptive forest management under climate change',
#  'integrating fire risk stand management scheduling an application to maritime pine stands portugal',
#  'stochastic approach to optimize maritime pine pinus pinaster ait stand management scheduling under fire risk an application portugal',
#  'decision support system for management planning of eucalyptus plantations facing climate change',
#  'addressing multicriteria forest management with pareto frontier methods an application portugal',
#  'developing wildfire risk probability models for eucalyptus globulus stands portugal',
#  'stochastic dynamic programming approach to optimize shortrotation coppice systems management scheduling an application to eucalypt plantations under wildfire risk portugal',
#  'assessing forest management strategies using contingent valuation approach and advanced visualisation techniques portuguese case study',
#  'an enterprise architecture approach to forest management support systems design an application to pulpwood supply management portugal',
#  'developing postfire eucalyptus globulus labill stand damage and tree mortality models for enhanced forest planning portugal',
#  'threestep approach to postfire mortality modelling maritime pine pinus pinaster ait stands for enhanced forest planning portugal',
#  'characterization of wildfires portugal',
#  'assessing impacts of common agricultural policy changes on regional land use patterns with decision support system',
#  'an approach to cork oak forest management planning case study southwestern portugal',
#  'aplicação da lógica fuzzy na análise sensorial de pão de forma enriquecido',
#  'produção de etanol partir de lactossoro industrial',
#  'effect of aqueous extract of the seaweed igracilaria domingensisi on the physicochemical microbiological and textural features of fermented milks',
#  'instrumental texture and sensory evaluation of fermented dairy beverages processed with reconstituted goat whey powder and coculture of streptococcus thermophilus and lactobacillus casei',
#  'comparison of dairy desserts produced with potentially probiotic mixed culture and dispersions obtained from gracilaria birdiae and gracilaria domingensis seaweeds used as thickening agents',
#  'aqueous extract of gracilaria birdiae plastino oliveira as texture modifier fermented milks',
#  'evaluation of bayesian network to classify clustered',
#  'classification of nodules mammograms image by using wavelet transform',
#  'investigation of clustered features for anautomated classifier as part of mammography cad scheme',
#  'classifying clusters of in digitized mammogramsby artificial neural network',
#  'comparing mammographic images analysis of intensity attributes',
#  'comparative study between powers of sigmoid functions mlp backpropagation and polynomials function approximation problems',
#  'tumoral mass classification by specialists and the cad scheme',
#  'evaluation of the clinical efficacy of minimally invasive procedures for breast cancer screening a teaching hospital',
#  'training system for digital mammographic diagnoses of breast cancer',
#  'breast density pattern characterization by histogram features and texture descriptors',
#  'automatic segmentation of breast masses using enhanced ica mixture model',
#  'novel mahalanobisbased feature selection improves oneclass classification of early hepatocellular carcinoma',
#  'performance of cad scheme applied to images obtained from mammographic film digitization and fullfield digital mammography ffdm',
#  'heritability and correlations of onion bulb traits allium cepa',
#  'screening cip potato germoplasm for resistance to bacterial wilt brazil methods and preliminary resulst',
#  'reaction of potato genotypes to bacterial wilt',
#  'reaction of brazilian potato varieties to bacterial wilt',
#  'search for sources of early blight alternaria solani field resistance not associated with vegetative late maturity tetraploid potato germoplasm',
#  'resistance to peronospora destructor onions',
#  'comparison of families from x crosses brazil',
#  'comparison of haploid tuberosumsolanum chacoense versus solanum phurejahaploid hybrids as staminate parents of 2x progenies evaluated under distinct crop management systems',
#  'complete coat protein nucleotide sequence of garlic common latent virus',
#  'molecular characterization of garlic commom latent virus gclv carlavirus garlic viral complex',
#  'molecular characterization of garlic common latent virus gclv carlavirus garlic viral complex',
#  'molecular characterization of garlic viral complex',
#  'evaluation brazil of potato clones resistant to bacterial wilt the philippines',
#  'reaction of brazilian potato varieties to bacterial',
#  'reaction of potato genotypes to bacterial wilt',
#  'multitrait selection system using populations with small number of interploid hybrid seedlings potato degree of highparent heterosis for yield and frequency of clones combining quantitative agronomic traits',
#  'potato solanum tuberosum production brazil',
#  'chomosome regions between centromeres and proximal crossovers are the prysical sites of major effects loci for yield potato genetic analysis employing meiotic mutants',
#  'effect of formation by first meiotic division restitution with and without croosover on eight quantitative traits 4x2x potato progenies',
#  'breeding potato germoplasm for resistance to viruses',
#  'breeding potato for cultivation the uplands of central brazil',
#  'direct estimation of the meiotic recombination on potato traits via analysis of progenies from synaptic mutants with formation by fdr without crossing',
#  'heterotic effects for yield and tubers solids and type of gene action for five traits 4x potato families derived from interploid crosses',
#  'environmental protection through resistant potato research education and delivering information brazil',
#  'brs ana cultivar de batata de duplo propósito',
#  'genetic diversity studies of brazilian garlic cultivars and quality control of garlicclover production',
#  'viral reinfection affecting bulb production garlic after seven years of cultivation under field conditions',
#  'detection of three allexivirus species infecting garlic brazil',
#  'extreme resistance to two brazilian strains of potato virus pvy transgenic potato cv achat expressing the pvyº coat protein',
#  'tuber yield and quality of fdr potato progenies derived from the wild diploid species solanum berthaultii and solanum tarijense',
#  'evaluation under longday conditions of progenies from crosses between potato cultivars and haploid tuberosumsolanum chacoense hybrids',
#  'flexibility components proprioceptive mechanisms and methods',
#  'predictive variables for postoperative pain after consecutive dental extraction surgeries',
#  'dermatoglyphic profile of physical strength brazilian paralympic power lifters',
#  'eosinophilic ulcer of oral mucosa case report',
#  'efeitos crônicos do flexionamento estático sobre parâmetros neuromusculares adultos jovens',
#  'dermatoglyphics correlation between software and traditional method kineanthropometric application',
#  'effects of concurrent physical exercise program on aerobic power and body composition adults',
#  'dermatoglyphic characteristics of hypertensives',
#  'static balance of elderly women submitted to physical activity program',
#  'muscle strength gh and levels older women submitted to land aquatic resistance training',
#  'diversity and abundance of litter frogs altitudinal sites serra do japi southeastern brazil',
#  'food habits and ontogenetic diet shifts of the litter dwelling frog proceratophrys boiei wied',
#  'diversity and evolution of macrohabitat use body size and morphology a monophyletic group of neotropical pitvipers bothrops',
#  'defensive behaviour pit vipers of the genus bothrops serpentes viperidae',
#  'comparative support for the niche variation hypothesis that more generalized populations also are more heterogeneous',
#  'usind stable isotopes to quantify individuallevel diet variation',
#  'the defensive strike of five species of lanceheads of the genus bothrops viperidae',
#  'individual specialization the hunting wasp trypoxylon trypargilum albonigrum hymenoptera crabronidae',
#  'intrapopulation diet variation four frogs leptodactylidae of the brazilian savannah',
#  'sex and season affect individuallevel diet variation the neotropical marsupial gracilinanus microtarsus didelphidae',
#  'gluttonous predators how to estimate prey size when there are too many prey',
#  'network analysis reveals contrasting effects of intraspecific competition on individual versus population diets',
#  'individuallevel diet variation four species of brazilian frogs',
#  'the shape of the competition and carrying capacity kernels affects the likelihood of disruptive selection',
#  'nested diets novel pattern of individuallevel resource use',
#  'why intraspecific trait variation matters community ecology',
#  'the nested assembly of individual resource networks',
#  'the effect of travel loss on the evolutionarily stable distributions of populations space',
#  'the ecological causes of individual specialization',
#  'hypothesistesting framework for studies investigating ontogenetic niche shifts using stable isotope ratios',
#  'partitioning the relative fitness effects of diet and trophic morphology the threespine stickleback',
#  'variation drives the seasonal dynamics the trophic niche of neotropical marsupial',
#  'multivariate models for correlated count data',
#  'isotopic discrimination factors and between tissues and diet of the broadsnouted caiman',
#  'latitudinal gradients intraspecific ecological diversity',
#  'ecosystem fragmentation drives increased diet variation an endemic livebearing fish of the bahamas',
#  'body size and allometric shape variation the molly poecilia vivipara along gradient of salinity and predation',
#  'network analyses support the role of prey preferences shaping resource use patterns within five animal populations',
#  'bothrops mattogrossensis mato grosso lancehead diet',
#  'individual specialization the huntingwasp trypoxylon trypargilum agamemnon richards hymenoptera crabronidae',
#  'functional morphology of the tetra fish differs between divergent habitats the pantanal wetlands',
#  'seasonal population and individual niche dynamics a tetra fish the pantanal wetlands',
#  'body streamlining related to higher growth rates bahamian mosquitofish',
#  'the dimensionality of individual niche variation',
#  'geographical and intrapopulation variation the diet of threatened marine predator ipontoporia blainvilleii cetacea',
#  'applying stable isotopes to examine foodweb structure an overview of analytical tools',
#  'nanoparticles applied to antineoplastic agents patent landscape',
#  'trends nanopharmaceutical patents',
#  'key molecules antiretrovirals synthesis',
#  'trends nanotechnology patents applied to the health sector',
#  'case study of patents related to captopril squibbs first blockbuster',
#  'prepared by the proteic sol gel process',
#  'auag nanostructures on pmma surface',
#  'increased oxygen radical and pancreatic damage',
#  'toxics effects of water euthrophication on pancreatic hepatic and osteogenic tissues of rats',
#  'protective effect of nickel chloride on superoxide damage enhacement of cu zn superoxide dismutase affinity to the oxygen free radical',
#  'clinical biochemical determination the mangalarga paulista horse reference values',
#  'high dietary carbohydrate and pancreatic lesion',
#  'intratracheal injection of nickel chloride and cu zn superoxide dismutase activity lung of rats',
#  'nickel chloride potential accumulation from the airway toxicokinetics rats',
#  'pancreas damage and intratracheal administration effects of nickel chloride',
#  'nickel chloride effects on erythrocyte generation of superoxide radical',
#  'influence of nickel chloride on irondeficiency rats',
#  'influence of nickel chloride on bone marrow of irondeficient rats',
#  'effect of nickel chloride on streptozotocin induced diabetes',
#  'nickel chloride protection against alloxanand diabetes',
#  'nickel choloride and diabetes ii calcium zinc phosphorus and iron determinations alloxan diabetic and rats treated by nickel chloride injections',
#  'nickel chloride and alloxan determination of glucose insulin and superoxide dismutase blood and pancreas of rats',
#  'effects of sodium and calcium concentrations on the potentiation of the responses of rabbit mesenteric and coeliac arteries to vasoconstrictor agonists',
#  'long term toxicity following acute administration of nickel',
#  'effect of water contamination with cadmium and nickel on tissues of rats',
#  'iron and trace elements rat cerebral structures',
#  'content of eight elements rat fetal pancreatic islet by neutron activation analysis',
#  'impact of an environmental realistic intake of water contaminants and superoxide formation on tissues of rats',
#  'toxic effects of alcohol intake on prostate of rats',
#  'free radical production by azomethine effects on pancreatic and hepatic tissues',
#  'toxicity of chronic ethanol ingestion and superoxide radical formation on seminal vesicles of rats',
#  'superoxide radical and toxicity of environmental nickel exposure',
#  'reactive oxygen generation of superoxide radical by azomethine a new antimalarial drug',
#  'serum biochemical determinations of propolis treated rats',
#  'superoxide radical tocopherol and cadmium toxicity',
#  'effect of alpha tocopherol on superoxide radical and toxicity of cadmium exposure',
#  'environmental cadmium exposure and metabolic responses of the nile tilapia oreochromis niloticus',
#  'superoxide radical and nephrotoxic effect of cadmium exposure',
#  'toxic mechanism of nickel exposure on cardiac tissue',
#  'toxic mechanism of cadmium exposure on cardiac tissue',
#  'the use of the oxidative stress responses as biomarkers nile tilapia exposed to vivo cadmium contamination',
#  'toxicity of ad libitum overfeeding effects on cardiac tissue',
#  'toxicity of dietary restriction of fat enriched diets on cardiac tissue',
#  'the adverse effect of high energy dense diet on cardiac tissue',
#  'dietary restriction and fiber supplementation oxidative stress and metabolic shifting for cardiac health',
#  'dietary restriction metabolic shifting for cardiac health',
#  'seasonal effect of brazilian propolis on seric biochemical variables',
#  'hypoglycaemic and antioxidant effects of onion allium cepa dietary onion addition antioxidant activity and hypoglycaemic effects on diabetic rats',
#  'cadmium the environment biomarker for evaluating cardiac toxicity',
#  'susceptibility to nephrotoxicity of streptozotocin induced diabetic rats exposed to cadmium',
#  'effects of cadmium exposure on survival growth and physiological status on nile tilapia',
#  'cadmium decreases confrontation fish',
#  'dietary copper cardioprotective hypoglycaemic hypolipidaemic and antioxidant effects on experimental diabetes',
#  'adverse metabolic effect of training and acute exercise rat myocardium',
#  'protective effect of naringerin on biochemical parameters diabetic rats',
#  'effects of copper intake on experimental diabetes dyslipidemic profile',
#  'relation between quercetin and diabetes mellitus effects on biochemical parameters',
#  'antioxidant effect of saponin potential action on risk factors atherosclerosis',
#  'serum oxidant status and lipid profile influence of olive oil and its minor constituents oleic acid and polyphenols',
#  'diets rich saturated and polyunsaturated fatty acids metabolic shifting and cardiac health',
#  'toxicity of hypercaloric diet and monosodium glutamate oxidative stress and metabolic shifting hepatic tissue',
#  'impact of the training program on lipid profile and cardiac health',
# ...
#  'vibrational spectra and dft calculations of sonderianin diterpene',
#  'new diterpene isolated from the resin of hymenaea courbaril',
#  'alterations brain amino acid metabolism and inhibitory effects on pkc are possibly correlated with anticonvulsant effects of the isomeric mixture of and amyrin from iprotium heptaphyllumi',
#  'vibrational properties of diterpene 4as acid studied by raman and infrared spectroscopy together with ab initio calculations',
#  'antifungal activity and synergistic effect of acetophenones isolated from species croton against dermatophytes ande yeasts',
#  'chemical composition antioxidant antifungal and hemolytic activities of essential oil from baccharis trinervis lam pers asteraceae',
#  'vibrational spectroscopy and dft calculations of flavonoid derriobtusone',
#  'spectroscopic and microbiological characterization of labdane diterpene isolated from the stems of croton jacobinensis',
#  'chemical composition and antioxidant activity of chemical constituents from croton zethntneri euphorbiaceae',
#  'chemical composition and larvicidal activity against aedes aegypti diptera culicidae of essential oils leaves stalks and roots of the croyon nepetaefilius baill euphorbiaceae',
#  'antibacterial effect on mature biofilms of oral streptococci and antioxidant activity of from combretum leprosum',
#  'tocoyena sellowiana extract decreases bone loss an experimental model of periodontitis rats putative role for and inhibition',
#  'analgesic and antiinflammatory activities of the isomeric mixture of alpha and betaamyrin from protium heptaphyllum aubl march',
#  'ix notes on the constitution of feminist youth brazil',
#  'dissecting the associations of endemic pemphigus foliaceus fogo selvagem with alleles and genotypes',
#  'polymorphisms within the tumor necrosis factor and lymphotoxinalpha genes and endemic pemphigus foliaceus are there any associations',
#  'dengue virus infections comparison of methods for diagnosing the acute disease',
#  'polymorphism of the promoter region and exon of the gene endemic pemphigus foliaceus fogo selvagem',
#  'expression profile of interferon stimulated genes central nervous system of mice infected with dengue virus',
#  'trypanosoma cruzi stagespecific calpainlike protein induced after various kinds of stress',
#  'genetic polymorphisms of the tcell coreceptors and in afro and eurobrazilians',
#  'characterization of a homologue of stressinduced in trypanosoma cruzi',
#  'trypanosoma cruzi infection induces global host cell response cardiomyocytes',
#  'profiling the trypanosoma cruzi phosphoproteome',
#  'molecular characterization of the trypanosoma cruzi specific rna binding protein and its associated mrnas',
#  'quantitative proteomics of trypanosoma cruzi during metacyclogenesis',
#  'the zinc finger protein binds target mrnas enriched during trypanosoma cruzi metacyclogenesis',
#  'comparison of two distinct murine macrophage gene expression profiles response to leishmania amazonensis infection',
#  'predicting the proteins of angomonas deanei strigomonas culicis and their respective endosymbionts reveals new aspects of the trypanosomatidae family',
#  'internal control for realtime polymerase chain reaction based on bacteriophage for rna viruses diagnostics',
#  'involvement of protein the differentiation process of trypanosoma cruzi',
#  'trypanosoma cruzi specific mrna amplification by vitro transcription improves parasite transcriptomics hostparasite rna mixtures',
#  'evolutionary analyses of myosin genes trypanosomatids show history of expansion secondary losses and',
#  'novel hepatitis virus genotyping method based on liquid microarray',
#  'managing grazing animals to achieve nutrient cycling and soil improvement notill integrated systems',
#  'replacement of corn grain by brown rice grain dairy cow rations nutritional and productive effects',
#  'the birth of new cropping system towards sustainability the subtropical lowland agriculture',
#  'tesis doctoral narrativas móviles estrategias discursivas modos de participación en arte locativo',
#  'initial growth of schizolobium parahybae brazilian cerrado soil under liming and mineral fertilization',
#  'delimitation of juvenile and mature woods of pinus caribaea var hondurensis sénécl wh barrett golfari as function of the length of the tracheids',
#  'boron fertilisation different phenological stages of soybean',
#  'forest structure and the species composition of the parque estadual mata atlântica located goiás state brazil',
#  'feline nasal granuloma due to cryptoccocus gattii type vgii',
#  'biosynthesis of phospholipases and proteinases using clinical and environmental strains of cryptococcus neoformans',
#  'fulltime teachers students and curriculum the singleshift model rio de janeiro',
#  'girassol webbased software project management tool',
#  'connecting thalamus and cortex the role of ephrins',
#  'axons of callosal neurons bifurcate transiently the white matter before consolidating an interhemispheric projection',
#  'acts as repulsive cue for migrating cortical interneurons',
#  'temporal and spatial regulation of interneuron distribution the developing cerebral cortex an vitro study',
#  'cenpj regulates progenitor divisions and neuronal migration the cerebral cortex downstream of',
#  'zika virus impairs growth human neurospheres and brain organoids',
#  'loss of cannabinoid cb receptors induces cortical migration malformations and increases seizure susceptibility',
#  'chloroquine an endocytosis blocking agent inhibits zika virus infection different cell models',
#  'zika virus disrupts molecular fingerprinting of human neurospheres',
#  'the cannabinoid receptor drives corticospinal motor neuron differentiation through the transcriptional regulation axis',
#  'olinked oligosaccharides present the cell wall of aspergillus fumigatus contain immunodominant epitopes',
#  'an ânbspglucan of pseudallescheria boydii involved fungal phagocytosis and tolllike receptor activation',
#  'biochemical characterization of potential virulence markers the human fungal pathogen',
#  'carbohydrates present the glycoprotein from conidia of the opportunistic pathogen scedosporium prolificans',
#  'monoclonal antibodies against of scedosporium apiospermum enhance the pathogenicity of the fungus',
#  'structures present the cell wall of the saprophytic fungus cladosporium hormoconis resinae',
#  'carbohydrate epitopes glycoprotein from the opportunistic fungal pathogen scedosporium apiospermum',
#  'glycoconjugates and polysaccharides from the boydii complex structural characterisation involvement cell differentiation cell recognition and virulence',
#  'dopamine upregulates phenotype from individuals with generalized anxiety disorder',
#  'sensitivity to glucocorticoid inhibition of vitroth17related cytokines production multiple sclerosis patients related to elevated plasma levels',
#  'oglycosylation cell wall proteins scedosporium prolificans critical for phagocytosis and inflammatory cytokines production by macrophages',
#  'negatively modulates the immune response a scedosporiosis murine model',
#  'the impact of maternal antiretroviral therapy on cytokine profile the uninfected neonates',
#  'construção otimização de um sistema para produção aplicação de ozônio escala de laboratório',
#  'novas tendências para tratamento de resíduos industriais contendo espécies organocloradas',
#  'biossensores amperométricos para determinação de compostos fenólicos amostras de interesse ambiental',
#  'electrochemical biosensorbased devices for continuous phenols monitoring environmental matrices',
#  'multielectrode detection voltammetry',
#  'some chemical and toxicological aspects about paper mill effluent treatment with ozone',
#  'degradation and toxicity reduction of textile effluent by combined photocatalytic and ozonation processes',
#  'effects of fungal laccase immobilization procedures for the development of biosensor for phenol compounds',
#  'remediation and toxicity removal from kraft paper mill effluent by ozonization',
#  'photoassisted electrochemical degradation of organic pollutants on dsa type oxide electrodenbsp process test for phenol synthetic solution and its application for the bleach kraft mill effluent',
#  'mixed enzyme remote electrochemical biosensor for monitoring phenolic compounds',
#  'laccasebased screen printed electrode for amperometric detection of phenolic compounds',
#  'direct electron transfer an approach for electrochemical biosensors with higher selectivity and sensitivity',
#  'electrochemical behavior of the complex immobilized on selfassembled monolayer modified electrode for lascorbic acid detection',
#  'highly stable amperometric biosensor for ethanol based on meldolas blue adsorbed on silica gel modified with niobium oxide',
#  'dual amperometric biosensor device for analysis of binary mixtures of phenols by multivariate calibration using partial least squares',
#  'effects of edta on signal stability during electrochemical detection of acetaminophen',
#  'application of selfassembled monolayerbased electrode for voltammetric determination of copper',
#  'polycrystaline gold electrodes comparative study of pretreatment procedures used for cleaning and thiol selfassembly monolayer formation',
#  'remediation of kraft and black liquor effluents by biological and chemical processes',
#  'studies on the electrochemical behavior of cystine selfassembled monolayer modified electrode using ferrocyanide as probe',
#  'ozonation of phenol',
#  'synthesis characterization and catalytic evaluation of cubic ordered mesoporous iron silicon oxides',
#  'behaviour of simgox hybrid composites on the solar photocatalytic degradation of polluted air',
#  'influence of neodymium ions on photocatalytic activity of synthesized by sol gel and precipitation methods',
#  'onepot green synthesis of cerium oxidecarbon microspheres and its catalytic ozonation activity',
#  'preparation and catalytic activity heterogeneous photocatalytic and ozonation processes',
#  'development of laccasebased injection electrochemical biosensor for phenolic compounds determination and its application for monitoring remediation of kraft paper mill effluent',
#  'leptospira interrogans serovar seropositivity and the reproductive performance of sows',
#  'methodology for photometric validation vehicles visual interactive systems',
#  'novel hybrid method for the segmentation of the coronary artery tree 2d angiograms',
#  'ranking approach for probe selection and classification of microarray data with artificial neural networks',
#  'milkde new approach for multiple instance learning based on positive instance selection and kernel density estimation',
#  'attenuation of experimental asthma by mycobacterial protein combined with cpg requires tlr9dependent signaling circuit',
#  'macrophages il33 treatment attenuate ongoing mycobacterium tuberculosis infection',
#  'topical prostaglandin analog restores defective dendritic cellmediated host defense against istaphylococcus aureusi the skin of diabetic mice',
#  'is negative regulator of metabolic reprogramming during sepsis',
#  'genetic background affects the expansion of macrophage subsets the lungs of mycobacterium hosts',
#  'domestic effluent treatment through integrated system of septic tank and root zone',
#  'nutrient removal from piggery effluent using vertical constructed wetlands southern brazil',
#  'characterization and wastewater treatment of winery located the midwest of santa catarina state south of brazil',
#  'constructed wetlands and sand filter applied as onsite posttreatment of anaerobic effluent',
#  'nitrogen transformation horizontal and vertical constructed wetlands applied for dairy cattle wastewater treatment southern brazil',
#  'experiências brasileiras wetlands construídos aplicados ao tratamento de águas residuárias parâmetros de projeto para sistemas horizontais',
#  'constructed wetlands for sludge dewatering with high solids loading rate and effluent recirculation characteristics of effluent produced and accumulated sludge',
#  'organic load and hydraulic regime influence the bacterial community responsible for the nitrogen cycling bed media of vertical subsurface constructed wetland',
#  'nitrogen transforming bacteria within fullscale partially saturated vertical subsurface constructed wetland treating urban wastewater',
#  'removal of organic carbon nitrogen emerging contaminants and fluorescing organic matter different constructed wetland configurations',
#  'terminology and computational linguistics new praxes terminography',
#  'sensitivity to camptothecin aspergillus nidulans identifies novel gene scaa related to the cellular dna damage response',
#  'the effect of carbon source and fluoride concentrations streptococcus mutans biofilm formation',
#  'fermentable and non fermentable sugars simple experiment of anaerobic metabolism',
#  'simple digestion procedure for the determination of cadmium cooper molibdenium and vanadium plants by graphite furnace atomic absorption spectrometry and mass inductively coupled plasma spectrometry',
#  'analysing ict and development from the perspective of the capabilities approach study south brazil',
#  'making sense to decreasing citizen eparticipation through social representation lens',
#  'journalistic performance latin america comparative study of professional roles news content',
#  'the effect of the lignan cubebin on doxorubicin mutagenicity and in wing somatic cells of drosophila melanogaster',
#  'trypanosoma cruzi evaluation of cubebin derivatives activity the messenger rnas processing',
#  'vitro efficacy of the essential oil of piper cubeba piperaceae against schistosoma mansoni',
#  'mutagenicity and antimutagenicity of hinokinin trypanosomicidal compound measured by salmonella microsome and comet assays',
#  'vivo infection by trypanosoma cruzi morphometric study of tissue changes mice',
#  'comparative study of the modulatory effects of on the induced by different chemical agents',
#  'evaluation of the vivo therapeutic properties of and against trypanosoma cruzi',
#  'the lignan displays modulatory effects on human monoamine and gaba transporter activities',
#  'vitro antiparasitic activity and chemical composition of the essential oil obtained from the fruits of piper cubeba',
#  'leishmanicidal effect of derivatives of lignans from piper cubeba',
#  'cubebin and hinokinin evaluation of immunomodulatory effects chagas disease',
#  'acvity of gochnatia pulchra',
#  'antibacterial activity of cubebin isolated from piper cubeba and its synthetic derivatives against microorganisms that cause endodontic infections',
#  'the lignan cubebin inhibits vascular contraction and induces relaxation via nitric oxide activation isolated rat aorta',
#  'antibacterial activity of isolated from piper cubeba and its semisynthetic derivatives against microorganisms that cause endodontic infections',
#  'induces arrest and contributes to the effects of doxorubicin breast cancer cells',
#  'stairways architecture learning objects as tool for developing concepts of similar triangles ratios proportions and thales theorem',
#  'applying modeldriven development for building customizable learning objects',
#  'criança o desenvolvimento infantil na perspectiva de mães usuárias do serviço público de saúde',
#  'prã¡ticas de educaã§ã£o relato de mã£es usuã¡rias de um serviã§o pãºblico de saãºde',
#  'desafios para ação interdisciplinar na atenção básica implicações relativas composição das equipes de saúde da família',
#  'riscos psicossociais incapacidade do servidor público um estudo de caso',
#  'effect of estradiol implantation the corticomedial amygdala on the sexual behavior of castrated male rats',
#  'pretraining adrenaline recovers the amnestic effect of metenkephalinin demedullated rats',
#  'administration of nanogram amounts of beta endorphin and met enkephalin causes retrograde amnesia rats',
#  'influence of the mother on the development of aggressive behavior of male rats',
#  'effects of administration of agonists on maternal aggression of rats',
#  'effects of stress on defensive aggression and dominance a water competition test',
#  ...]

# %% [markdown]
# ## Remove no english docs and save

# %%
data = ''
for document in data_clean:
    lang, log_prob = langid.classify(document)
    if lang == 'en':
        data += document + '\n'

# %%
with gzip.open(OUT_FILE, 'wb', compresslevel=9) as f:
    f.write(data.encode())
