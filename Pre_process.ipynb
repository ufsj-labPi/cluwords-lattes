# %%
import os
import pandas as pd
import string
import re
import langid

import numpy as np

from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from IPython.display import clear_output
from langid.langid import LanguageIdentifier, model

#BASE_FILE = '/home/antonio/old_things/data.csv'
BASE_FILE = 'data/data.csv'
OUT_FILE = 'data/data_pp.csv'

# %% [markdown]
# ## Read Data

# %%
data = pd.read_csv(BASE_FILE, sep='|', index_col=0)
sw_path = os.path.abspath("./stopwords.txt")
sw = stopwords.words(sw_path)

data['pp_title'] = None
data['pp_title_rm_sw'] = None
data['pp_tile_rm_sw_lem'] = None

# %%
data.head()
# Out:
#           author_id                    author_name  \
# 0  9179745776599946     Vanderlei Moraes Rodrigues
# 1  9103101956717062           Rafael Santos Coelho
# 2  9120445622048393            Luiz Henrique Gomes
# 3  9120445622048393            Luiz Henrique Gomes
# 4  9175591364526313  Lisane Brisolara de Brisolara
#
#                                           author_ref               doctorate  \
# 0                                   RODRIGUES, V. M.              Computação
# 1                    COELHO, R. S.;COELHO, RAFAEL S.   Ciência da Computação
# 2                        GOMES, L. H.;GOMES, LUIZ H.  Ciências da Computação
# 3                        GOMES, L. H.;GOMES, LUIZ H.  Ciências da Computação
# 4  BRISOLARA, Lisane;Brisolara, Lisane;BRISOLARA,...              Computação
#
#   paper_issn paper_ano                                              paper  \
# 0   01034308      2000  Using the ACL2 Theorem Prover to Reason about ...
# 1   15710653      2015  The k-hop connected dominating set problem: ha...
# 2   02195259      2009  QUANTIFYING SOCIAL AND OPPORTUNISTIC BEHAVIOR ...
# 3   01665316      2007     Workload models of spam and legitimate e-mails
# 4   18071953      2004  Supporting Collaboration in Distributed Design...
#
#                     paper_home_page pp_title pp_title_rm_sw pp_tile_rm_sw_lem
# 0                               NaN     None           None              None
# 1  [doi:10.1016/j.endm.2015.07.011]     None           None              None
# 2   [doi:10.1142/s0219525909002088]     None           None              None
# 3                               NaN     None           None              None
# 4                               NaN     None           None              None

# %% [markdown]
# ## Remove punctuation, stopwords, invalid text and applies lemmatization

# %%
def to_lower(text):
    text = [word.lower() for word in text.split()]
    return " ".join(text)

# %%
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# %%
def remove_stopwords(text, sw):
    text = [word for word in text.split() if word not in sw]
    return " ".join(text)

# %%
def lemmatizer_text(text):
    lemmatizer = WordNetLemmatizer()
    text = word_tokenize(text)
    for index, word in enumerate(text):
            text[index] = lemmatizer.lemmatize(word)
    return ' '.join(text)

# %%
def remove_invalid(text):
    noise_file = open('noise.txt', 'r')
    noise = noise_file.read()
    text = remove_punctuation(text)
    text = re.sub('\n', ' ', text)
    text = re.sub(' +', ' ', text)
    text = text.split(' ')
    text2 = ''
    for index, word in enumerate(text):
        if(len(word) < 2 or len(word) > 16):
            text.pop(index)
        elif word in noise:
            text.pop(index)
        elif word.isnumeric():
            text.pop(index) 
    for word in text:
        text2 += word + ' '
    text2 = text2[:-1]
    return text2

# %%
n_titles = data.shape[0]
for index, row in data.iterrows():
    #text = to_lower(data.at[index, 'article'])
    text = to_lower(data.at[index, 'paper'])
    text = remove_invalid(text)
    #lang, log_prob = langid.classify(text)
    #data.at[index, 'is_english'] = lang + ' ' + str(log_prob)
    lang, log_prob = langid.classify(text)
    if lang == 'en':
        data.at[index, 'pp_title'] = text
        text = remove_stopwords(text, sw)
        data.at[index, 'pp_title_rm_sw'] = text
        text = lemmatizer_text(text)
        data.at[index, 'pp_tile_rm_sw_lem'] = text
    clear_output(wait=True)
    print(str("%.2f" % (index * 100 / n_titles)) + '%')
# Out:
# 100.00%

# %%
data
# Out:
#               author_id                          author_name  \
# 0      9179745776599946           Vanderlei Moraes Rodrigues
# 1      9103101956717062                 Rafael Santos Coelho
# 2      9120445622048393                  Luiz Henrique Gomes
# 3      9120445622048393                  Luiz Henrique Gomes
# 4      9175591364526313        Lisane Brisolara de Brisolara
# ...                 ...                                  ...
# 26235  2283022405554044     Marco Aurelio Cavalcanti Pacheco
# 26236  2283022405554044     Marco Aurelio Cavalcanti Pacheco
# 26237  2283022405554044     Marco Aurelio Cavalcanti Pacheco
# 26238  2203695060210682                  Thiago José Machado
# 26239  2262290755400077  Adriana Cristina Ferrari dos Santos
#
#                                               author_ref  \
# 0                                       RODRIGUES, V. M.
# 1                        COELHO, R. S.;COELHO, RAFAEL S.
# 2                            GOMES, L. H.;GOMES, LUIZ H.
# 3                            GOMES, L. H.;GOMES, LUIZ H.
# 4      BRISOLARA, Lisane;Brisolara, Lisane;BRISOLARA,...
# ...                                                  ...
# 26235  Pacheco, M. A. C.;PACHECO, Marco Aurélio C.;Pa...
# 26236  Pacheco, M. A. C.;PACHECO, Marco Aurélio C.;Pa...
# 26237  Pacheco, M. A. C.;PACHECO, Marco Aurélio C.;Pa...
# 26238                  Machado, T. J.;MACHADO, THIAGO J.
# 26239                                   SANTOS, A. C. F.
#
#                      doctorate paper_issn paper_ano  \
# 0                   Computação   01034308      2000
# 1        Ciência da Computação   15710653      2015
# 2       Ciências da Computação   02195259      2009
# 3       Ciências da Computação   01665316      2007
# 4                   Computação   18071953      2004
# ...                        ...        ...       ...
# 26235         Computer Science   09204105      2017
# 26236         Computer Science   09521976      2018
# 26237         Computer Science   17518725      2018
# 26238  Modelagem Computacional   01704214      2016
# 26239      Computação Aplicada   09574174      2008
#
#                                                    paper  \
# 0      Using the ACL2 Theorem Prover to Reason about ...
# 1      The k-hop connected dominating set problem: ha...
# 2      QUANTIFYING SOCIAL AND OPPORTUNISTIC BEHAVIOR ...
# 3         Workload models of spam and legitimate e-mails
# 4      Supporting Collaboration in Distributed Design...
# ...                                                  ...
# 26235  Uncertainty quantification in reservoir simula...
# 26236  Solving stochastic differential equations thro...
# 26237  An Efficient Model Based on Genetic Programmin...
# 26238  A new one-shot pointwise source reconstruction...
# 26239  Detecting attack signatures in the real networ...
#
#                                          paper_home_page  \
# 0                                                    NaN
# 1                       [doi:10.1016/j.endm.2015.07.011]
# 2                        [doi:10.1142/s0219525909002088]
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 26235                 [doi:10.1016/j.petrol.2017.03.046]
# 26236                                                NaN
# 26237                    [doi:10.1049/iet-map.2017.0490]
# 26238  [http://onlinelibrary.wiley.com/doi/10.1002/mm...
# 26239                   [doi:10.1016/j.eswa.2007.03.011]
#
#                                                 pp_title  \
# 0      using the acl2 theorem prover to reason about ...
# 1      the khop connected dominating set problem hard...
# 2      quantifying social and opportunistic behavior ...
# 3          workload models of spam and legitimate emails
# 4      supporting collaboration distributed design en...
# ...                                                  ...
# 26235  uncertainty quantification reservoir simulatio...
# 26236  solving stochastic differential equations thro...
# 26237  an efficient model based on genetic programmin...
# 26238  new oneshot pointwise source reconstruction me...
# 26239  detecting attack signatures the real network t...
#
#                                           pp_title_rm_sw  \
# 0             acl2 theorem prover reason vhdl components
# 1      khop connected dominating set problem hardness...
# 2      quantifying social opportunistic behavior emai...
# 3                 workload models spam legitimate emails
# 4      supporting collaboration distributed design en...
# ...                                                  ...
# 26235  uncertainty quantification reservoir simulatio...
# 26236  solving stochastic differential equations gene...
# 26237  efficient model based genetic programming spli...
# 26238     oneshot pointwise source reconstruction method
# 26239  detecting attack signatures real network traff...
#
#                                        pp_tile_rm_sw_lem
# 0              acl2 theorem prover reason vhdl component
# 1      khop connected dominating set problem hardness...
# 2      quantifying social opportunistic behavior emai...
# 3                   workload model spam legitimate email
# 4      supporting collaboration distributed design en...
# ...                                                  ...
# 26235  uncertainty quantification reservoir simulatio...
# 26236  solving stochastic differential equation genet...
# 26237  efficient model based genetic programming spli...
# 26238     oneshot pointwise source reconstruction method
# 26239  detecting attack signature real network traffi...
#
# [26240 rows x 11 columns]

# %%
data.loc[data['pp_title'].notnull()]
# Out:
#               author_id                          author_name  \
# 0      9179745776599946           Vanderlei Moraes Rodrigues
# 1      9103101956717062                 Rafael Santos Coelho
# 2      9120445622048393                  Luiz Henrique Gomes
# 3      9120445622048393                  Luiz Henrique Gomes
# 4      9175591364526313        Lisane Brisolara de Brisolara
# ...                 ...                                  ...
# 26235  2283022405554044     Marco Aurelio Cavalcanti Pacheco
# 26236  2283022405554044     Marco Aurelio Cavalcanti Pacheco
# 26237  2283022405554044     Marco Aurelio Cavalcanti Pacheco
# 26238  2203695060210682                  Thiago José Machado
# 26239  2262290755400077  Adriana Cristina Ferrari dos Santos
#
#                                               author_ref  \
# 0                                       RODRIGUES, V. M.
# 1                        COELHO, R. S.;COELHO, RAFAEL S.
# 2                            GOMES, L. H.;GOMES, LUIZ H.
# 3                            GOMES, L. H.;GOMES, LUIZ H.
# 4      BRISOLARA, Lisane;Brisolara, Lisane;BRISOLARA,...
# ...                                                  ...
# 26235  Pacheco, M. A. C.;PACHECO, Marco Aurélio C.;Pa...
# 26236  Pacheco, M. A. C.;PACHECO, Marco Aurélio C.;Pa...
# 26237  Pacheco, M. A. C.;PACHECO, Marco Aurélio C.;Pa...
# 26238                  Machado, T. J.;MACHADO, THIAGO J.
# 26239                                   SANTOS, A. C. F.
#
#                      doctorate paper_issn paper_ano  \
# 0                   Computação   01034308      2000
# 1        Ciência da Computação   15710653      2015
# 2       Ciências da Computação   02195259      2009
# 3       Ciências da Computação   01665316      2007
# 4                   Computação   18071953      2004
# ...                        ...        ...       ...
# 26235         Computer Science   09204105      2017
# 26236         Computer Science   09521976      2018
# 26237         Computer Science   17518725      2018
# 26238  Modelagem Computacional   01704214      2016
# 26239      Computação Aplicada   09574174      2008
#
#                                                    paper  \
# 0      Using the ACL2 Theorem Prover to Reason about ...
# 1      The k-hop connected dominating set problem: ha...
# 2      QUANTIFYING SOCIAL AND OPPORTUNISTIC BEHAVIOR ...
# 3         Workload models of spam and legitimate e-mails
# 4      Supporting Collaboration in Distributed Design...
# ...                                                  ...
# 26235  Uncertainty quantification in reservoir simula...
# 26236  Solving stochastic differential equations thro...
# 26237  An Efficient Model Based on Genetic Programmin...
# 26238  A new one-shot pointwise source reconstruction...
# 26239  Detecting attack signatures in the real networ...
#
#                                          paper_home_page  \
# 0                                                    NaN
# 1                       [doi:10.1016/j.endm.2015.07.011]
# 2                        [doi:10.1142/s0219525909002088]
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 26235                 [doi:10.1016/j.petrol.2017.03.046]
# 26236                                                NaN
# 26237                    [doi:10.1049/iet-map.2017.0490]
# 26238  [http://onlinelibrary.wiley.com/doi/10.1002/mm...
# 26239                   [doi:10.1016/j.eswa.2007.03.011]
#
#                                                 pp_title  \
# 0      using the acl2 theorem prover to reason about ...
# 1      the khop connected dominating set problem hard...
# 2      quantifying social and opportunistic behavior ...
# 3          workload models of spam and legitimate emails
# 4      supporting collaboration distributed design en...
# ...                                                  ...
# 26235  uncertainty quantification reservoir simulatio...
# 26236  solving stochastic differential equations thro...
# 26237  an efficient model based on genetic programmin...
# 26238  new oneshot pointwise source reconstruction me...
# 26239  detecting attack signatures the real network t...
#
#                                           pp_title_rm_sw  \
# 0             acl2 theorem prover reason vhdl components
# 1      khop connected dominating set problem hardness...
# 2      quantifying social opportunistic behavior emai...
# 3                 workload models spam legitimate emails
# 4      supporting collaboration distributed design en...
# ...                                                  ...
# 26235  uncertainty quantification reservoir simulatio...
# 26236  solving stochastic differential equations gene...
# 26237  efficient model based genetic programming spli...
# 26238     oneshot pointwise source reconstruction method
# 26239  detecting attack signatures real network traff...
#
#                                        pp_tile_rm_sw_lem
# 0              acl2 theorem prover reason vhdl component
# 1      khop connected dominating set problem hardness...
# 2      quantifying social opportunistic behavior emai...
# 3                   workload model spam legitimate email
# 4      supporting collaboration distributed design en...
# ...                                                  ...
# 26235  uncertainty quantification reservoir simulatio...
# 26236  solving stochastic differential equation genet...
# 26237  efficient model based genetic programming spli...
# 26238     oneshot pointwise source reconstruction method
# 26239  detecting attack signature real network traffi...
#
# [24760 rows x 11 columns]

# %%
data.loc[data['pp_title'].notnull()].to_csv('data/all_data_clean.csv', sep='|')

# %%
data.loc[data['pp_title'].notnull()]
# Out:
#                      id                      name  \
# 0      3172487852109469  Abdelhakim Senhaji Hafid
# 1      3172487852109469  Abdelhakim Senhaji Hafid
# 3      3172487852109469  Abdelhakim Senhaji Hafid
# 4      3172487852109469  Abdelhakim Senhaji Hafid
# 5      3172487852109469  Abdelhakim Senhaji Hafid
# ...                 ...                       ...
# 39313  1531713258988427                Zhao Liang
# 39314  1531713258988427                Zhao Liang
# 39315  1531713258988427                Zhao Liang
# 39316  1531713258988427                Zhao Liang
# 39317  1531713258988427                Zhao Liang
#
#                                            name_citation  \
# 0      HAFID, A. S.;A. HAFID;HAFID, ABDELHAKIM;HAFID,...
# 1      HAFID, A. S.;A. HAFID;HAFID, ABDELHAKIM;HAFID,...
# 3      HAFID, A. S.;A. HAFID;HAFID, ABDELHAKIM;HAFID,...
# 4      HAFID, A. S.;A. HAFID;HAFID, ABDELHAKIM;HAFID,...
# 5      HAFID, A. S.;A. HAFID;HAFID, ABDELHAKIM;HAFID,...
# ...                                                  ...
# 39313           L. ZHAO;Zhao, L.;ZHAO, LIANG;LIANG, ZHAO
# 39314           L. ZHAO;Zhao, L.;ZHAO, LIANG;LIANG, ZHAO
# 39315           L. ZHAO;Zhao, L.;ZHAO, LIANG;LIANG, ZHAO
# 39316           L. ZHAO;Zhao, L.;ZHAO, LIANG;LIANG, ZHAO
# 39317           L. ZHAO;Zhao, L.;ZHAO, LIANG;LIANG, ZHAO
#
#                                        doctorate  \
# 0      Computer Science and Operational Research
# 1      Computer Science and Operational Research
# 3      Computer Science and Operational Research
# 4      Computer Science and Operational Research
# 5      Computer Science and Operational Research
# ...                                          ...
# 39313         Engenharia Eletrônica e Computação
# 39314         Engenharia Eletrônica e Computação
# 39315         Engenharia Eletrônica e Computação
# 39316         Engenharia Eletrônica e Computação
# 39317         Engenharia Eletrônica e Computação
#
#                                                  article  article_year  \
# 0      Performance Management of IEEE 802.15.4 Wirele...        2015.0
# 1      An Integrated Predictive Mobile-Oriented Bandw...        2014.0
# 3      Cross-layer aware joint design of sensing and ...        2016.0
# 4      An Enhanced Reservation Based Medium Access Co...        2012.0
# 5      Path-Based QoS Provisioning for Optical Burst ...        2011.0
# ...                                                  ...           ...
# 39313  Semi-Supervised Learning Guided by the Modular...        2012.0
# 39314  Selecting salient objects in real scenes: An o...        2011.0
# 39315  Characterizing chaotic melodies in automatic m...        2010.0
# 39316  Phase-disorder-induced double resonance of neu...        2010.0
# 39317  Chaotic phase synchronization and desynchroniz...        2009.0
#
#       is_english                                           pp_title  \
# 0           None  performance management of ieee wireless sensor...
# 1           None  an integrated predictive mobileoriented framew...
# 3           None  crosslayer aware joint design of sensing and f...
# 4           None  an enhanced reservation based medium access co...
# 5           None  pathbased qos provisioning for optical burst s...
# ...          ...                                                ...
# 39313       None  semisupervised learning guided by the modulari...
# 39314       None  selecting salient objects real scenes an oscil...
# 39315       None  characterizing chaotic melodies automatic musi...
# 39316       None              double resonance of neuronal activity
# 39317       None  chaotic phase synchronization and in an oscill...
#
#                                           pp_title_rm_sw  \
# 0      performance management ieee wireless sensor ne...
# 1      integrated predictive mobileoriented framework...
# 3      crosslayer aware joint design sensing frame du...
# 4      enhanced reservation based medium access contr...
# 5      pathbased qos provisioning optical burst switc...
# ...                                                  ...
# 39313  semisupervised learning guided modularity meas...
# 39314  selecting salient objects real scenes oscillat...
# 39315  characterizing chaotic melodies automatic musi...
# 39316                 double resonance neuronal activity
# 39317  chaotic phase synchronization oscillator netwo...
#
#                                        pp_tile_rm_sw_lem
# 0      performance management ieee wireless sensor ne...
# 1      integrated predictive mobileoriented framework...
# 3      crosslayer aware joint design sensing frame du...
# 4      enhanced reservation based medium access contr...
# 5      pathbased qos provisioning optical burst switc...
# ...                                                  ...
# 39313  semisupervised learning guided modularity meas...
# 39314  selecting salient object real scene oscillator...
# 39315  characterizing chaotic melody automatic music ...
# 39316                 double resonance neuronal activity
# 39317  chaotic phase synchronization oscillator netwo...
#
# [28711 rows x 10 columns]
